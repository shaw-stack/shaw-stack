# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
x=[4,5,6,7,8,9,2,3,11]
y=[21,22,32,24,29,13,14,15,27]
data=list(zip(x,y))
Kmeans=KMeans(n_clusters=2)
Kmeans.fit(data)
plt.scatter(x,y,c=Kmeans.labels_)
plt.show()
