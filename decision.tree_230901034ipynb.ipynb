# %%
import matplotlib.pyplot as plt
import pandas
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
df=pandas.read_csv("/content/tree - Sheet1.csv")
print(df)
d={'uk':0,'usa':1,'n':2,'india':3}
df['Nationality']=df['Nationality'].map(d)
d={'yes':1,'no':0}
df['Go']=df['Go'].map(d)
features=['Age','Experience','Rank','Nationality']
x=df[features]
y=df['Go']
dtree=DecisionTreeClassifier()
dtree=dtree.fit(x,y)
tree.plot_tree(dtree,feature_names=features)
plt.show()
# Out:
#    Age  Experience  Rank Nationality   Go
# 0   35          10     9          uk  yes
# 1   45           5     9         usa   no
# 2   39           6     8           n   no
# 3   40           9     9           n  yes
# 4   29           7     7          uk   no
# 5   49           8     9       india   no
# 6   38           3     4          uk  yes
# 7   46          14     6           n   no
# 8   38          12     7       india  yes
